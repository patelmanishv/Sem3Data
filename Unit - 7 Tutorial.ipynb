# %% [markdown]
# ## Modules and directories - 5 marks (~offline)
# **Module**
# - Module is a python file and a collection of statements,variables,functions and classes
# - It can be written in C / python
# - There are two types
#   - Inbuilt modules
#   - user defined modules

# %% [markdown]
# ## Inbuilt modules

# %%
import math

# %%
math.cos(2 * math.pi)

# %%
math.sin(math.pi/2)

# %% [markdown]
# ## Alternate way - import specific methods

# %%
from math import pi,cos,sin

# %%
cos(2*pi)

# %%
sin(pi/2)

# %% [markdown]
# ## Creating aliases or alternate names

# %%
from math import cos as cosine, pi as pieee

# %%
cosine(2*pieee)

# %% [markdown]
# ## Userdefined modules

# %% [markdown]
# ### Create a module

# %%
pwd

# %%
# %%writefile newmodule.py
x = 1000
y = [7,8,9]
def hello(z):
    return z

# %% [markdown]
# ## Import the module

# %%
import newmodule

# %%
dir(newmodule)

# %%
print(newmodule.x)
print(newmodule.y)
print(newmodule.hello("python"))

# %%
print(x)

# %%
from newmodule import x,y

# %%
print(x)

# %%
from newmodule import x as myvariable

# %%
print(myvariable)

# %% [markdown]
# ## Package
# - A package is a collection of modules

# %% [markdown]
# ## Create package modules

# %%
# %%writefile pkg/mod1.py
s = [3,4,5]
def hi(x):
    print("mod1 hi")

# %%
# %%writefile pkg/mod2.py
s = [30,40,50]
def hi(x):
    print("mod2 hi")

# %% [markdown]
# ## Import modules from the package

# %%
import pkg.mod1,pkg.mod2

# %%
pkg.mod1.hi("hello")

# %%
pkg.mod2.hi("hello")

# %% [markdown]
# ## `os` module
# - The os module is an inbuilt python module which provides methods for python to interact with the host operating system

# %%
import os

# %%
os.name

# %%
os.cpu_count()

# %% [markdown]
# ## os.getcwd()
# - This method returns the current working directory

# %%
os.getcwd()

# %% [markdown]
# ## os.mkdir(path)
# - This method create a directory at specified path

# %%
os.mkdir("Mydirectory")

# %% [markdown]
# ### Create directories and sudirectories

# %%
os.makedirs("Newdir/subdir")

# %% [markdown]
# ## listdir()
# - Returns the list of the directories and subdirectories present

# %%
os.listdir()

# %%
os.listdir(r"C:\Users\LJENG\Desktop")

# %%
os.listdir("C:\\Users\\LJENG\\Desktop")

# %%
os.listdir("C:/Users/LJENG/Desktop")

# %% [markdown]
# ## rmdir(path)
# - This method removes the directory **provided it is empty** at specified path

# %%
import os

# %%
os.rmdir("Mydirectory")

# %%
os.rmdir("C:/Users/LJENG/Desktop/desktopfolder")

# %% [markdown]
# ## remove(path)
# - It removes the file at the specified path

# %%
os.remove("C:/Users/LJENG/Desktop/myfile.txt")

# %% [markdown]
# ## chdir(path)
# - It changes the current working directory to the specified path

# %%
os.chdir("D://")

# %%
os.getcwd()
# Out:
# 'D:\\'

# %% [markdown]
# ## PB PROGRAMS

# %% [markdown]
# ## 496
# ```
# Write a python program to make named stringmodule which contain stringlength without spaces and stringreverse functions related to string and import that module in another file and use that fuctions with string given by user.
# ```

# %%
# %%writefile stringmodule.py
def stringlength(s):
    return len(s) - s.count(" ")
def stringreverse(s):
    return s[::-1]
# Out:
# Writing stringmodule.py

# %%
import stringmodule

# %%
stringmodule.stringlength("hello world")
# Out:
# 10

# %%
stringmodule.stringreverse("hello world")
# Out:
# 'dlrow olleh'

# %% [markdown]
# ## 497
# ```
# Write a python program to create a directory and subdirectory. It should print the current working directory path and list of names of files present in the given directory.
# ```

# %%
import os

# %%
os.makedirs("folder1/subfolder1")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.vscode',
#  '.vscode-cli',
#  '3D Objects',
#  'anew.txt',
#  'anewfile.txt',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'example.txt',
#  'example1.txt',
#  'example2.txt',
#  'Favorites',
#  'folder1',
#  'hello.txt',
#  'hello1.txt',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'LskLock.tmp',
#  'magicfile.txt',
#  'mbox-short.txt',
#  'Music',
#  'My Documents',
#  'myfile.txt',
#  'mymodule.py',
#  'mynewfile.txt',
#  'NetHood',
#  'New Text Document.txt',
#  'Newdir',
#  'newmodule.py',
#  'newone.txt',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
# ...

# %% [markdown]
# ## 498
# ```
# Write a python program to make a module named cal.py which contain all the basic functions related to calculator like
# addition, subtraction, multiplication, and division import that module in another file and use that functions with number
# inputs given by user.
# ```

# %%
# %%writefile cal.py
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y
def div(x,y):
    return x/y
# Out:
# Writing cal.py

# %%
import cal

# %%
print(cal.add(10,5))
print(cal.sub(10,5))
print(cal.mul(10,5))
print(cal.div(10,5))
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# ## 499
# ```
# Write a program to create a module ‘first_word.py’, which returns the first word of any string passed. Show the working of
# the module, by calling the module with any suitable example.
#  Input: ‘This is Python Programming’
#  Output: ‘This’
#  ```

# %%
# %%writefile first_word.py
def first(s):
    return s.split()[0]
# Out:
# Writing first_word.py

# %%
import first_word

# %%
first_word.first("This is programming")
# Out:
# 'This'

# %%
pwd
# Out:
# 'D:\\'

# %%
os.chdir(r"C:\Users\LJENG")

# %%
with open("mbox-short.txt") as f:
    lines = f.readlines()
    sum1 = 0
    count = 0
    for line in lines:
        s = line.split()
        if len(s) ==2 :
            if s[0] == "X-DSPAM-Confidence:":
                sum1+=float(s[1])
                count+=1
    print("average", sum1/count)
# Out:
# average 0.7507185185185187
