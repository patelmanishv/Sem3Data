# %% [markdown]
# ### T-3 syllabus
# ```
# Unit - 6 - Files handling ~ 10 marks
# Unit - 7 - Modules and Git ~ 5 marks
# Unit - 8 - Exceptions handling and Introduction to OOP ~ 10 Marks
# ```

# %% [markdown]
# # Unit - 6 File handling

# %%
pwd

# %% [markdown]
# ## Create text file

# %%
# %%writefile magicfile.txt
# This is a overwritten file

# %% [markdown]
# ### Reading a file
# **SYNTAX**
#
# ```PYTHON
# Signature:
# open(
#     file,
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None,
# )
# ```
# ```
# Character Meaning
# --------- ---------------------------------------------------------------
# 'r'       open for reading (default)
# 'w'       open for writing, truncating the file first
# 'x'       create a new file and open it for writing
# 'a'       open for writing, appending to the end of the file if it exists
# 'b'       binary mode
# 't'       text mode (default)
# '+'       open a disk file for updating (reading and writing)
# 'U'       universal newline mode (deprecated)
# ```

# %%
file = open("magicfile.txt")

# %%
file

# %% [markdown]
# ## file methods
# ```
# 6.2 Reading data from files -read(), readline(), readlines(), seek()
# and tell() functions
# ```

# %% [markdown]
# ## read

# %%
file.read()

# %%
file.read()

# %%
file.close()

# %%
file = open("magicfile.txt")

# %%
file.read(2)

# %%
file.read()

# %% [markdown]
# ## close

# %%
file.close()

# %%
# %%writefile newfile.txt
# this

# %%
file = open("newfile.txt")

# %%
file.read(-9)

# %%
len("\n")

# %%
file.read??

# %%
file.close()

# %% [markdown]
# ## Reading an encoded file

# %%
file = open("alice.txt", encoding='utf-8')

# %%
print(file.read())

# %%
file.close()

# %%
# %%writefile smiley.txt
# આ ગુજરાતી છે 😀.

# %%
file = open("smiley.txt",encoding='utf-8')

# %%
file.read()

# %%
file.close()

# %% [markdown]
# ## File attributes
# ```
# closed,mode,name,readable,writable
# ```

# %%
file = open("smiley.txt")

# %%
file.closed

# %%
file.mode

# %%
file.name

# %%
file.readable()

# %%
file.writable()

# %%
file.close()

# %%
file.closed

# %%
file.mode

# %%
file.name

# %%
file.readable()

# %%
file.writable()

# %% [markdown]
# ## readline method
#
# ```
# This method enables reading one line at a time
# ```

# %%
# %%writefile hello.txt
# this
# is
# python

# %%
file = open("hello.txt")

# %%
file.readline(4)

# %%
file.readline()

# %%
file.readline()

# %%
file.readline()

# %%
file.close()

# %%
file.readline??

# %% [markdown]
# ## readlines method
# ```
# Return a list of lines from the stream.
# ```

# %%
file = open("hello.txt")

# %%
file.readlines()

# %% [markdown]
# ## WAP to find number of lines in alice.txt

# %%
file = open("alice.txt",encoding='utf-8')

# %%
len(file.readlines())

# %%
file.close()

# %% [markdown]
# ## reading bytes in readlines

# %%
file = open("hello.txt")
"""
this
is
python
"""

# %%
file.readlines(300)

# %%
file.readlines(2)

# %%
file.close()

# %% [markdown]
# ## Looping through file object

# %%
file = open("hello.txt")

# %%
for i in file:
    print(i)

# %% [markdown]
# ## Writing files
# ```
# file.write, file.writelines
# ```

# %%
file = open("hello.txt", 'w')

# %%
file.write(" This is not java")

# %%
file.close()

# %%
file.write??

# %% [markdown]
# ## writelines method

# %%
l = ['hi\n', 'hello\n', 'how are you']

# %%
f = open("hello.txt", 'w')

# %%
f.writelines(l)

# %%
f.close()

# %%
f = open("hello.txt")

# %%
f.read()

# %%
f.close()

# %% [markdown]
# ## Writing hello world 100 times in a file

# %%
bigl = ['hello world\n' for i in range(100)]
file = open("new.txt", 'w')
file.writelines(bigl)
file.close()

# %%
file = open('hi.txt', 'w')

# %%
file.write("hello")
# Out:
# 5

# %%
file.close()

# %%
file = open('hi.txt', 'a')
file.write("appended to the line")
file.close()

# %% [markdown]
# ## 80 Character limit

# %%
def formatlines(inputfile,outputfile,maxlength=80):
    infile = open(inputfile)
    outfile = open(outputfile,'w')
    
    for line in infile:
        words = line.split()
        current = ""
        for word in words:
            if current == "":
                newline = word
            else:
                newline = current + " " + word
            if len(newline) <= maxlength:
                current = newline
            else:
                outfile.write(current + "\n")
                current = word
        if current:
            outfile.write(current + "\n")
    infile.close()
    outfile.close()

# %% [markdown]
# ## `with` context manager

# %%
# %%writefile hello.txt
# this is python
# Out:
# Overwriting hello.txt

# %%
file = open("hello.txt")

# %%
file.closed
# Out:
# False

# %%
file.read()
# Out:
# 'this is python\n'

# %%
file.read()
# Out:
# ''

# %%
file.close()

# %%
with open("hello.txt") as file:
    print(file.read())
file.closed
# Out:
# this is python
# True

# %% [markdown]
# ## tell method

# %%
file = open("hello.txt")

# %%
file.read(2)
# Out:
# 'th'

# %%
file.tell()
# Out:
# 2

# %%
file.read(3)
# Out:
# 'is '

# %%
file.tell()
# Out:
# 5

# %% [markdown]
# ## seek method
# - It sets the pointer to the desired location

# %%
file.seek(0)
# Out:
# 0

# %%
file.read(2)
# Out:
# 'th'

# %%
file.read(3)
# Out:
# 'is '

# %%
file.seek(5)
# Out:
# 5

# %%
file.read()
# Out:
# 'is python\n'
