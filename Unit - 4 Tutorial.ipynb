# %% [markdown]
# ## SYLLABUS FOR T-2 EXAM
#
# - Unit 4 (Immutable data structures - string and tuple)(10 Marks)
# - Unit 5 (Mutable data structures - List, Dictionary and set/frozenset)(15 Marks)

# %% [markdown]
# # STRING DATA STRUCTURE

# %%
s = 'LJU'
print(s)
print(id(s))
s = s+"2025"
print(s)
print(id(s))
# Out:
# LJU
# 1830330964848
# LJU2025
# 1830330995824

# %% [markdown]
# ## Typecasting

# %%
a = 10
print(a, id(a), type(a))
a = str(a)
print(a, id(a), type(a))
# Out:
# 10 140733919275072 <class 'int'>
# 10 1830330998384 <class 'str'>

# %% [markdown]
# ## INDEXING

# %%
s = 'hello world'
print(s[0])
print(s[-1])
print(s[2])
print(s[-3])
print(s[10])
# Out:
# h
# d
# l
# r
# d

# %% [markdown]
# ## IMMUTABILITY

# %%
s = "hello"
s[0] = 'z' # Throws an error

# %% [markdown]
# ## SLICING

# %%
s = "hello world"
# print("1 - ", s[0:6:2])
# print("2 - ", s[2:4:2])
# print("3 - ", s[2::-1])
# print("4 - ", s[:-1:3])
# print("5 - ", s[::2])
# print("6 - ", s[0:7:3])
# print("7 - ", s[2:-1:2])
# print("8 - ", s[:-2:2])
# print("9 - ", s[1:-1:3])
print("10 - ", s[-5:-1:-2])
# print("11 - ", s[-5::])
# Out:
# 10 -

# %%
s = "hello"

# %%
print(s)
# Out:
# hello

# %%
s=s[::-1]

# %%
print(s)
# Out:
# olleh

# %% [markdown]
# ## Comparison

# %%
print("gandhi" == "Gandhi")
# Out:
# False

# %%
print("gandhi" < "Gandhi")
# Out:
# False

# %%
print(ord('g'), ord("G"))
# Out:
# 103 71

# %%
print("gAndhi" < "gandhi")
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
print("hello" or "world")
print("hello" and "world")
# Out:
# hello
# world

# %%
print(not "")
# Out:
# True

# %% [markdown]
# ## Looping through string

# %%
s = 'hello'
for i in s:
    print(i,end = " ")
# Out:
# h e l l o

# %%
s = "hi"
for i in s:
    print("hello")
# Out:
# hello
# hello

# %% [markdown]
# ## Enumerate

# %%
enumerate??

# %%
s = 'hello'
for i, j in enumerate(s):
    print(i, "--", j)
# Out:
# 0 -- h
# 1 -- e
# 2 -- l
# 3 -- l
# 4 -- o

# %% [markdown]
# ## MEMBERSHIP OPERATOR

# %%
print('z' in 'python')
print('m' not in "python")
# Out:
# False
# True

# %%
print('pt' in 'python')
# Out:
# False

# %% [markdown]
# ## Keywords

# %%
import keyword

# %%
keyword.kwlist

# %% [markdown]
# ## Universal Methods
# - `len, max, min, sorted`

# %%
s = 'hello world'
print(len(s))
print(min(s))
print(max(s))
print(sorted(s,reverse=True))
# Out:
# 11
#
# w
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# ## Write a program to characters and spaces in a given string
# ```
# Input = "This is a python tutorial"
# Output = Spaces : 4; Characters = 21
# ```

# %% [markdown]
# ## STRING ATTRIBUTES AND METHODS

# %%
s = 'THis is a python programming tutorial'

# %%
dir(s)

# %% [markdown]
# ## Capitalize

# %%
s.capitalize()
# Out:
# 'This is a python programming tutorial'

# %%
print(s)
# Out:
# THis is a python programming tutorial

# %% [markdown]
# ## Upper

# %%
s.upper()
# Out:
# 'THIS IS A PYTHON PROGRAMMING TUTORIAL'

# %% [markdown]
# ## Lower

# %%
s.lower()
# Out:
# 'this is a python programming tutorial'

# %% [markdown]
# ## Title

# %%
s.title()
# Out:
# 'This Is A Python Programming Tutorial'

# %% [markdown]
# ## Swapcase

# %%
s.swapcase()
# Out:
# 'thIS IS A PYTHON PROGRAMMING TUTORIAL'

# %% [markdown]
# ## Count

# %%
s.count('i', 15, 100)
# Out:
# 2

# %%
s.count('i', 15)
# Out:
# 2

# %% [markdown]
# ## Find

# %%
print(s)
s.find('is')
# Out:
# THis is a python programming tutorial
# 2

# %%
s.find('iz')
# Out:
# -1

# %%
print(s)
s.find('is',3)
# Out:
# THis is a python programming tutorial
# 5

# %% [markdown]
# ## index

# %%
s.index??

# %%
print(s)
print(s.index('is'))
# print(s.index('iz')) # Throws ValueError
print(s.index('is',3))
# Out:
# THis is a python programming tutorial
# 2
# 5

# %% [markdown]
# ## startswith

# %%
print(s.startswith("Th"))
print(s.startswith("TH"))
# Out:
# False
# True

# %% [markdown]
# ## endswith

# %%
print(s.endswith("al "))
print(s.endswith("al"))
# Out:
# False
# True

# %% [markdown]
# ## isalnum()

# %%
"12345*".isalnum()
# Out:
# False

# %% [markdown]
# ## isalpha()

# %%
print("this".isalpha())
print("this8".isalpha())
# Out:
# True
# False

# %% [markdown]
# ## isupper() and islower()

# %%
print("This".isupper())
print("THIS".isupper())
print("this".islower())
print("THIS".islower())
# Out:
# False
# True
# True
# False

# %% [markdown]
# ## isnumeric()

# %%
"123abc".isnumeric()
# Out:
# False

# %%
"123".isnumeric()
# Out:
# True

# %%
"3.14".isnumeric()
# Out:
# False

# %%
"%".isnumeric()
# Out:
# False

# %% [markdown]
# ## isdigit()

# %%
"123.45".isdigit()
# Out:
# False

# %%
"123".isdigit()
# Out:
# True

# %% [markdown]
# ## islower(), isupper(), istitle() and isspace()

# %%
print("this".islower())
print("THIS".isupper())
print("This Is".istitle())
print(" ".isspace())
# Out:
# True
# True
# True
# True

# %%
print(s)
# Out:
# THis is a python programming tutorial

# %% [markdown]
# ## SPLIT METHOD

# %%
s.split()
# Out:
# ['THis', 'is', 'a', 'python', 'programming', 'tutorial']

# %%
s.split(maxsplit=1)
# Out:
# ['THis', 'is a python programming tutorial']

# %%
s1 = "This.is.python"
s1.split(".",1)
# Out:
# ['This', 'is.python']

# %% [markdown]
# ## JOIN

# %%
"".join(["this", 'is', 'python'])
# Out:
# 'thisispython'

# %%
" ".join(["this", 'is', 'python'])
# Out:
# 'this is python'

# %%
"$".join(["this", 'is', 'python'])
# Out:
# 'this$is$python'

# %%
"👨".join("python")
# Out:
# 'p👨y👨t👨h👨o👨n'

# %% [markdown]
# ## Replace

# %%
print(s)
# Out:
# THis is a python programming tutorial

# %%
s.replace('is','iz')
# Out:
# 'THiz iz a python programming tutorial'

# %%
s.replace('is','iz',1)
# Out:
# 'THiz is a python programming tutorial'

# %% [markdown]
# ## STRIP METHOD

# %%
"   hello    ".strip()
# Out:
# 'hello'

# %%
"   hello".strip()
# Out:
# 'hello'

# %%
"hello     ".strip()
# Out:
# 'hello'

# %%
"This is python".strip("hTno")
# Out:
# 'is is pyt'

# %% [markdown]
# ## maketrans and translate() method

# %%
intab = "aeiou"
outtab = "12345"
mystring = "This is a string function"
table = mystring.maketrans(intab,outtab)
print(table)
newstring = mystring.translate(table)
print(newstring)
# Out:
# {97: 49, 101: 50, 105: 51, 111: 52, 117: 53}
# Th3s 3s 1 str3ng f5nct34n

# %% [markdown]
# ## Remove punctuations

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
mystring = "T&h%i?s i!s [a] st^rin?g f{unctio}n"
table = mystring.maketrans('','',string.punctuation)
print(table)
newstring = mystring.translate(table)
print(newstring)
# Out:
# {33: None, 34: None, 35: None, 36: None, 37: None, 38: None, 39: None, 40: None, 41: None, 42: None, 43: None, 44: None, 45: None, 46: None, 47: None, 58: None, 59: None, 60: None, 61: None, 62: None, 63: None, 64: None, 91: None, 92: None, 93: None, 94: None, 95: None, 96: None, 123: None, 124: None, 125: None, 126: None}
# This is a string function

# %% [markdown]
# ## del method

# %%
s = 'hello'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eecf8a7ba24f> in <module>
#       1 s = 'hello'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %% [markdown]
# ## WAP to implement the find method using `findchar` function in string

# %% [markdown]
# ## Write a program to shift a number based on following conditions -
#
# ```
# input - 12345
# shift - 1 -> output = 23451
# shift - 2 -> output = 34512
# shift - 3 -> output = 45123
# shift - 4 -> output = 51234
# shift - 5 -> output = 12345
# shift >=6 -> output = 54321
# ```

# %%
def shifting(number,shift):
    strnumber = str(number)
    digits = len(strnumber)
    
    if shift > digits:
        result = strnumber[::-1]
    else:
        result = strnumber[shift:] + strnumber[:shift]
    
    return int(result)

# %%
shifting(12345,6)
# Out:
# 54321

# %% [markdown]
# ## WAP to convert the first and last character of a word in a given string to upper case
#
# ```
# input - this is python
# output - ThiS IS PythoN
# ```

# %%
mystring = "this is python"
s = mystring.title()
print(s)
m = s.split()
# Out:
# This Is Python

# %%
print(m)
# Out:
# ['This', 'Is', 'Python']

# %%
result = ""
for i in m:
    result+=  i[:-1] + i[-1].upper() + " "

# %%
print(result)
# Out:
# ThiS IS PythoN

# %% [markdown]
# #### Q 312
# ```
# Write a python program to check the validity of a Password.
# Primary conditions for password validation:
# 1. Minimum 8 characters.
# 2. The alphabet must be between [a-z]
# 3. At least one alphabet should be of Upper Case [A-Z]
# 4. At least 1 number or digit between [0-9]
# 5. At least 1 character from [ _ or @ or $]
# Examples:
# Input: Ram@_f1234
# Output: Valid Password
# Input: Rama_fo$ab
# Output: Invalid Password
# Explanation: Number is missing
# Input: Rama#fo9c
# Output: Invalid Password
# Explanation: Must consist from _ or @ or $
# ```

# %%
def passwordcheck(password):
    l,u,p,d = 0,0,0,0
    if len(password) >= 8:
        for i in password:
            if i.islower():
                l+=1
            if i.isupper():
                u+=1
            if i.isdigit():
                d+=1
            if i in "@_$":
                p+=1
        if l>=1 and u>=1 and p>=1 and d>=1 and l+u+p+d == len(password):
            print("valid")
        else: 
            print("invalid")
    else:
        print("invalid")

# %%
password = input("Enter password ")
passwordcheck(password)
# Out:
# Enter password Ram@f1234
# valid

# %%
s = "1+2+1+1+1+3+3+4+5+2"
t = s.split("+")
print(t)
# Out:
# ['1', '2', '1', '1', '1', '3', '3', '4', '5', '2']

# %%
a = sorted(t)
print(a)
# Out:
# ['1', '1', '1', '1', '2', '2', '3', '3', '4', '5']

# %%
"+".join(a)
# Out:
# '1+1+1+1+2+2+3+3+4+5'

# %% [markdown]
# ## Balanced string program

# %% [markdown]
# ```
# input s1 = lk
#       s2 = ljku
# output - balanced strings
# ```

# %% [markdown]
# # TUPLE
# - Immutable
# - Ordered (index and slicing)
# - Heterogeneous elements

# %% [markdown]
# ## Creating tuple

# %%
t = (1,"hi",[1,2,3], None)

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = ('hi',)
type(t)
# Out:
# tuple

# %%
t= (5)
type(t)
# Out:
# int

# %% [markdown]
# ## zipping

# %%
t1 = (1,2,3)
t2 = (4,5,6,7)
t = zip(t1,t2)
print(t)
t = tuple(zip(t1,t2))
print(t)
# Out:
# ...
# ((1, 4), (2, 5), (3, 6))

# %% [markdown]
# ## Tuple packing and unpacking

# %%
a = 1,2,3,4
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
m,n,o,p = a
print(m,n,o,p)
# Out:
# 1 2 3 4

# %% [markdown]
# ## Taking input from the user

# %%
tuple1 = eval(input("Enter numbers separated by commas - "))
print(tuple1)
print(type(tuple1))
# Out:
# Enter numbers separated by commas - 3,4,5,6
# (3, 4, 5, 6)
# <class 'tuple'>

# %% [markdown]
# ## Type conversion

# %%
s = 'hello'
t = tuple(s)
print(t)
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
l = [2,3,4]
t = tuple(l)
print(t)
# Out:
# (2, 3, 4)

# %% [markdown]
# # ` + and *`

# %%
t1 = (1,2,3)
t2 = (4,5,6)

# %%
t1 + t2
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t1*t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-1b4b44ba1da1> in <module>
# ----> 1 t1*t2
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
t1*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %% [markdown]
# ## Membership operators

# %%
8 in (7,8,9)
# Out:
# True

# %%
9 not in (5,6,7)
# Out:
# True

# %% [markdown]
# ## ITERATING THROUGH TUPLE

# %%
t = (4,5,6)
for i in t:
    print(t)
# Out:
# (4, 5, 6)
# (4, 5, 6)
# (4, 5, 6)

# %%
t = (4,5,6)
for i in t:
    print(i)
# Out:
# 4
# 5
# 6

# %%
for i,j in enumerate(t):
    print(i,j)
# Out:
# 0 4
# 1 5
# 2 6

# %% [markdown]
# ## Comparing tuples

# %%
(1,2,3) == (2,3,1)
# Out:
# False

# %%
(1,2,3) < (1,3,2)
# Out:
# True

# %%
(1,2,3) < (1,1,4)
# Out:
# False

# %%
(1,2,"a") < (1,2,"A")
# Out:
# False

# %%
(1,2,"a") < ('a',2,"A")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5a7733e097d2> in <module>
# ----> 1 (1,2,"a") < ('a',2,"A")
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# ## UNIVERSAL METHODS
# ` len, min, max, sum,sorted`

# %%
t = (8,5,9,1,6,2,3,4)
print(len(t))
print(min(t))
print(max(t))
print(sum(t))
print(sorted(t))
print(sorted(t, reverse=True))
# Out:
# 8
# 1
# 9
# 38
# [1, 2, 3, 4, 5, 6, 8, 9]
# [9, 8, 6, 5, 4, 3, 2, 1]

# %%
t = ("python","cat","there", "java")
sorted(t)
# Out:
# ['cat', 'java', 'python', 'there']

# %%
t = ("python","cat","there", "java")
sorted(t, key = len)
# Out:
# ['cat', 'java', 'there', 'python']

# %%
t = ("python","cat","there", "java")
sorted(t, key = len,reverse=True)
# Out:
# ['python', 'there', 'java', 'cat']

# %% [markdown]
# ## Tuple methods

# %%
t = (6,5,5,5,3,4,7,8,5)

# %% [markdown]
# ## count

# %%
t.count(5)
# Out:
# 4

# %%
t.count(5,2) # count() takes exactly one argument (2 given)

# %% [markdown]
# ## index

# %%
t.index(5)
# Out:
# 1

# %%
print(t)
# Out:
# (6, 5, 5, 5, 3, 4, 7, 8, 5)

# %%
t.index(5,4)
# Out:
# 8

# %%
t.index?? # Documentation on index

# %% [markdown]
# ## Generator

# %%
x = (i**2 for i in (3,4,5,6))
print(x)
# Out:
# <generator object <genexpr> at 0x000001DB22BDB740>

# %%
next(x)
# Out:
# 9

# %%
next(x)
# Out:
# 16

# %%
next(x)
# Out:
# 25

# %%
next(x)
# Out:
# 36

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-47-92de4e9f6b1e> in <module>
# ----> 1 next(x)
#
# StopIteration:

# %%
t= tuple(x)
print(t)
# Out:
# ()

# %%
x = (i**2 for i in (3,4,5,6))
print(x)
# Out:
# <generator object <genexpr> at 0x000001DB228F1970>

# %%
t= tuple(x)
print(t)
# Out:
# (9, 16, 25, 36)

# %%
next(x)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-57-92de4e9f6b1e> in <module>
# ----> 1 next(x)
#
# StopIteration:

# %% [markdown]
# ## Comprehension

# %%
x = [i**2 for i in (3,4,5,6)]
print(x)
# Out:
# [9, 16, 25, 36]

# %%
x = [i**2 for i in (3,4,5,6) if i**2 > 20]
print(x)
# Out:
# [25, 36]

# %% [markdown]
# ## WAP to return the maximum even number from a given tuple
#
# ```
# input - (8,7,2,3,4,5,100,3,56,101)
# output - 100
#
# ```

# %%
t = max(i for i in (8,7,2,3,4,5,100,3,56,101) if i%2 == 0)
print(t)
# Out:
# 100

# %%
t = tuple(i for i in (8,7,2,3,4,5,100,3,56,101) if i%2 == 0)
print(t)
# Out:
# (8, 2, 4, 100, 56)

# %%
t = tuple(sorted(tuple(i for i in (8,7,2,3,4,5,100,3,56,101) if i%2 == 0)))
print(t)
# Out:
# (2, 4, 8, 56, 100)

# %% [markdown]
# ## PB 314 Ceaser cipher
# ```
# Write a Python program to create a Caesar encryption.
#  Note: In cryptography, a Caesar cipher, also known as Caesar's cipher, the shift cipher, Caesar's code or Caesar
# shift, is one of the simplest and most widely known encryption techniques. It is a type of substitution cipher in
# which each letter in the plaintext is replaced by a letter some fixed number of positions down the alphabet. For
# example, with a right shift of 3, A would be replaced by D, E would become H, and so on. The method is named
# after Julius Caesar, who used it in his private correspondence.
#  For Example:
#  Input Text  : LJIET ENG
#  Shift : 3
#  Cipher:  OMLHW HQJ
#  ```

# %%
def encrypt(message,key):
    message = message.upper()
    alpha = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    result = ''
    
    for letter in message:
        if letter in alpha:
            letterindex = (alpha.find(letter) + key) % 26
            result = result + alpha[letterindex]
        else:
            result+=letter
    return result

# %%
encrypt("ljiet eng",3)
# Out:
# 'OMLHW HQJ'

# %% [markdown]
# ## WAP to replace special symbols in a given string to `#
# ```
# input l^j$i[e?t
# output l#j#i#e#t
# ```

# %%
import string
s = input("Enter string - ")
for i in string.punctuation:
    s = s.replace(i,"#")
print(s)
# Out:
# Enter string - l^j$i[e?t
# l#j#i#e#t

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ## WAP to find sum of negative numbers in a given tuple
#
# ```
# input - (-1,-4,-3,-2,1,2,3,4,5,6)
# output = -10
#
# ```

# %%
sum(i for i in eval(input("Enter comma separated numbers")) if i < 0 )
# Out:
# Enter comma separated numbers-2,-4,1,2,4
# -6
